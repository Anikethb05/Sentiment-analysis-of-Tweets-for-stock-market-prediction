# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('stock_tweets.csv')

# %%
df.head()
# Out:
#                         Date  \
# 0  2022-09-29 23:41:16+00:00
# 1  2022-09-29 23:24:43+00:00
# 2  2022-09-29 23:18:08+00:00
# 3  2022-09-29 22:40:07+00:00
# 4  2022-09-29 22:27:05+00:00
#
#                                                Tweet Stock Name Company Name
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.

# %%
df['Stock Name'].unique()
# Out:
# array(['TSLA', 'MSFT', 'PG', 'META', 'AMZN', 'GOOG', 'AMD', 'AAPL',
#        'NFLX', 'TSM', 'KO', 'F', 'COST', 'DIS', 'VZ', 'CRM', 'INTC', 'BA',
#        'BX', 'NOC', 'PYPL', 'ENPH', 'NIO', 'ZS', 'XPEV'], dtype=object)

# %%
df.shape
# Out:
# (80793, 4)

# %%
df.describe()
# Out:
#                              Date                         Tweet Stock Name  \
# count                       80793                         80793      80793
# unique                      64424                         64479         25
# top     2022-07-07 18:32:41+00:00  $TSLA will triple in 2022 🚀🌕       TSLA
# freq                           14                            25      37422
#
#        Company Name
# count         80793
# unique           25
# top     Tesla, Inc.
# freq          37422

# %%
df.columns
# Out:
# Index(['Date', 'Tweet', 'Stock Name', 'Company Name'], dtype='object')

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
#import unicodedata

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\anike\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
def get_sentiment(text):
    sentiment = analyzer.polarity_scores(str(text))  
    return pd.Series([sentiment['compound'], sentiment['neg'], sentiment['neu'], sentiment['pos']])

# %%
df[['sentiment_score', 'Negative', 'Neutral', 'Positive']] = df['Tweet'].apply(get_sentiment)

# %%
df.head()
# Out:
#                         Date  \
# 0  2022-09-29 23:41:16+00:00
# 1  2022-09-29 23:24:43+00:00
# 2  2022-09-29 23:18:08+00:00
# 3  2022-09-29 22:40:07+00:00
# 4  2022-09-29 22:27:05+00:00
#
#                                                Tweet Stock Name Company Name  \
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.
#
#    sentiment_score  Negative  Neutral  Positive
# 0           0.0772     0.127    0.758     0.115
# 1           0.0000     0.000    1.000     0.000
# 2           0.2960     0.000    0.951     0.049
# 3          -0.7568     0.273    0.590     0.137
# 4          -0.8750     0.526    0.474     0.000

# %%
 df['Stock Name'].unique()
# Out:
# array(['TSLA', 'MSFT', 'PG', 'META', 'AMZN', 'GOOG', 'AMD', 'AAPL',
#        'NFLX', 'TSM', 'KO', 'F', 'COST', 'DIS', 'VZ', 'CRM', 'INTC', 'BA',
#        'BX', 'NOC', 'PYPL', 'ENPH', 'NIO', 'ZS', 'XPEV'], dtype=object)

# %% [markdown]
# ## Take "AMAZON" as example stock

# %%
stock_name = 'AMZN'

# %%
amzn_df = df[df['Stock Name'] == stock_name].copy()

# %%
amzn_df
# Out:
#                             Date  \
# 48351  2022-09-29 22:40:47+00:00
# 48352  2022-09-29 22:23:54+00:00
# 48353  2022-09-29 18:34:51+00:00
# 48354  2022-09-29 15:57:59+00:00
# 48355  2022-09-29 15:10:30+00:00
# ...                          ...
# 52435  2021-09-30 20:50:16+00:00
# 52436  2021-09-30 19:45:13+00:00
# 52437  2021-09-30 18:01:19+00:00
# 52438  2021-09-30 17:56:14+00:00
# 52439  2021-09-30 01:59:22+00:00
#
#                                                    Tweet Stock Name  \
# 48351  A group of lawmakers led by Sen. Elizabeth War...       AMZN
# 48352  $NIO just because I'm down money doesn't mean ...       AMZN
# 48353  Today’s drop in $SPX is a perfect example of w...       AMZN
# 48354  Druckenmiller owned $CVNA this year \nMunger b...       AMZN
# 48355  Top 10 $QQQ Holdings \n\nAnd Credit Rating\n\n...       AMZN
# ...                                                  ...        ...
# 52435  My top 10 holdings make up 66% of my portfolio...       AMZN
# 52436  Amazon $AMZN has 4X the market cap of Alibaba ...       AMZN
# 52437  Returns over the last 10 Years:\n\nBitcoin $BT...       AMZN
# 52438  Great snapshot of what it looks like when an i...       AMZN
# 52439  Shopify is now 9% of US e-commerce. It really ...       AMZN
#
#            Company Name  sentiment_score  Negative  Neutral  Positive
# 48351  Amazon.com, Inc.          -0.0772     0.084    0.841     0.075
# 48352  Amazon.com, Inc.           0.2500     0.158    0.684     0.158
# 48353  Amazon.com, Inc.          -0.3182     0.164    0.728     0.108
# 48354  Amazon.com, Inc.           0.2382     0.065    0.851     0.083
# 48355  Amazon.com, Inc.           0.7783     0.000    0.799     0.201
# ...                 ...              ...       ...      ...       ...
# 52435  Amazon.com, Inc.           0.4515     0.000    0.928     0.072
# 52436  Amazon.com, Inc.          -0.5106     0.095    0.873     0.032
# 52437  Amazon.com, Inc.          -0.2263     0.089    0.821     0.091
# 52438  Amazon.com, Inc.           0.9369     0.000    0.740     0.260
# 52439  Amazon.com, Inc.           0.5809     0.000    0.759     0.241
#
# [4089 rows x 8 columns]

# %%
amzn_df['Date'] = pd.to_datetime(amzn_df['Date'])

# %%
amzn_df['Date'] = amzn_df['Date'].dt.date

# %%
amzn_df.head()
# Out:
#              Date                                              Tweet  \
# 48351  2022-09-29  A group of lawmakers led by Sen. Elizabeth War...
# 48352  2022-09-29  $NIO just because I'm down money doesn't mean ...
# 48353  2022-09-29  Today’s drop in $SPX is a perfect example of w...
# 48354  2022-09-29  Druckenmiller owned $CVNA this year \nMunger b...
# 48355  2022-09-29  Top 10 $QQQ Holdings \n\nAnd Credit Rating\n\n...
#
#       Stock Name      Company Name  sentiment_score  Negative  Neutral  \
# 48351       AMZN  Amazon.com, Inc.          -0.0772     0.084    0.841
# 48352       AMZN  Amazon.com, Inc.           0.2500     0.158    0.684
# 48353       AMZN  Amazon.com, Inc.          -0.3182     0.164    0.728
# 48354       AMZN  Amazon.com, Inc.           0.2382     0.065    0.851
# 48355       AMZN  Amazon.com, Inc.           0.7783     0.000    0.799
#
#        Positive
# 48351     0.075
# 48352     0.158
# 48353     0.108
# 48354     0.083
# 48355     0.201

# %%
#amzn_df = amzn_df.drop(columns=['Negative', 'Positive', 'Neutral', 'Stock Name', 'Company Name'])

# %%
amzn_df.head()
# Out:
#              Date                                              Tweet  \
# 48351  2022-09-29  A group of lawmakers led by Sen. Elizabeth War...
# 48352  2022-09-29  $NIO just because I'm down money doesn't mean ...
# 48353  2022-09-29  Today’s drop in $SPX is a perfect example of w...
# 48354  2022-09-29  Druckenmiller owned $CVNA this year \nMunger b...
# 48355  2022-09-29  Top 10 $QQQ Holdings \n\nAnd Credit Rating\n\n...
#
#       Stock Name      Company Name  sentiment_score  Negative  Neutral  \
# 48351       AMZN  Amazon.com, Inc.          -0.0772     0.084    0.841
# 48352       AMZN  Amazon.com, Inc.           0.2500     0.158    0.684
# 48353       AMZN  Amazon.com, Inc.          -0.3182     0.164    0.728
# 48354       AMZN  Amazon.com, Inc.           0.2382     0.065    0.851
# 48355       AMZN  Amazon.com, Inc.           0.7783     0.000    0.799
#
#        Positive
# 48351     0.075
# 48352     0.158
# 48353     0.108
# 48354     0.083
# 48355     0.201

# %%
daily_sentiment = amzn_df.groupby('Date').mean(numeric_only=True)

# %%
daily_sentiment.head()
# Out:
#             sentiment_score  Negative   Neutral  Positive
# Date
# 2021-09-30         0.246480  0.036800  0.824200  0.139200
# 2021-10-01         0.359337  0.021875  0.863750  0.114375
# 2021-10-02        -0.000700  0.056333  0.846667  0.097000
# 2021-10-03         0.834400  0.000000  0.830000  0.170000
# 2021-10-04         0.258650  0.015583  0.883750  0.100583

# %%
all_stocks = pd.read_csv('stock_yfinance_data.csv')
print(all_stocks.shape)
all_stocks.head()
# Out:
# (6300, 8)
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 1  2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2  2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 3  2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 4  2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
#
#      Volume Stock Name
# 0  53868000       TSLA
# 1  51094200       TSLA
# 2  91449900       TSLA
# 3  55297800       TSLA
# 4  43898400       TSLA

# %%
stock_df = all_stocks[all_stocks['Stock Name'] == 'AMZN']

# %%
stock_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1008  2021-09-30  165.800003  166.392502  163.699493  164.251999  164.251999
# 1009  2021-10-01  164.450500  165.458496  162.796997  164.162994  164.162994
# 1010  2021-10-04  163.969498  163.999496  158.812500  159.488998  159.488998
# 1011  2021-10-05  160.225006  163.036499  160.123001  161.050003  161.050003
# 1012  2021-10-06  160.676498  163.216995  159.931000  163.100494  163.100494
# ...          ...         ...         ...         ...         ...         ...
# 1255  2022-09-23  116.000000  116.050003  112.059998  113.779999  113.779999
# 1256  2022-09-26  113.300003  117.339996  113.129997  115.150002  115.150002
# 1257  2022-09-27  117.199997  118.320000  113.050003  114.410004  114.410004
# 1258  2022-09-28  114.379997  118.699997  113.800003  118.010002  118.010002
# 1259  2022-09-29  115.599998  116.070000  113.059998  114.800003  114.800003
#
#         Volume Stock Name
# 1008  56848000       AMZN
# 1009  56712000       AMZN
# 1010  90462000       AMZN
# 1011  65384000       AMZN
# 1012  50660000       AMZN
# ...        ...        ...
# 1255  65126700       AMZN
# 1256  62723300       AMZN
# 1257  60094700       AMZN
# 1258  55763800       AMZN
# 1259  58969700       AMZN
#
# [252 rows x 8 columns]

# %%
stock_df['Date'] = pd.to_datetime(stock_df['Date'])
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_23188\3629404903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_df['Date'] = pd.to_datetime(stock_df['Date'])

# %%
stock_df.head()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1008 2021-09-30  165.800003  166.392502  163.699493  164.251999  164.251999
# 1009 2021-10-01  164.450500  165.458496  162.796997  164.162994  164.162994
# 1010 2021-10-04  163.969498  163.999496  158.812500  159.488998  159.488998
# 1011 2021-10-05  160.225006  163.036499  160.123001  161.050003  161.050003
# 1012 2021-10-06  160.676498  163.216995  159.931000  163.100494  163.100494
#
#         Volume Stock Name
# 1008  56848000       AMZN
# 1009  56712000       AMZN
# 1010  90462000       AMZN
# 1011  65384000       AMZN
# 1012  50660000       AMZN

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(stock_df['Date'], stock_df['Close'], color='#008B8B')
ax.set(xlabel="Date", ylabel="USD", title=f"{stock_name} Stock Price")
plt.show()

# %%
def get_tech_ind(d):
    data=d.copy()
    data['MA7'] = data.iloc[:,4].rolling(window=7).mean() #Close column
    data['MA20'] = data.iloc[:,4].rolling(window=20).mean() #Close Column
    data['MA10'] = data['Close'].rolling(window=10).mean()

    data['MACD'] = data.iloc[:,4].ewm(span=26).mean() - data.iloc[:,1].ewm(span=12,adjust=False).mean()
    #This is the difference of Closing price and Opening Price

    # Create Bollinger Bands
    data['20SD'] = data.iloc[:, 4].rolling(20).std()
    data['upper_band'] = data['MA20'] + (data['20SD'] * 2)
    data['lower_band'] = data['MA20'] - (data['20SD'] * 2)

    # Create Exponential moving average
    data['EMA'] = data.iloc[:,4].ewm(com=0.5).mean()

    # Create LogMomentum
    data['logmomentum'] = np.log(data.iloc[:,4] - 1)

    return data

# %%
tech_df = get_tech_ind(stock_df)
stock_df = tech_df.iloc[20:,:].reset_index(drop=True)
stock_df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-10-28  170.104996  173.949997  169.300003  172.328506  172.328506
# 1 2021-10-29  165.001007  168.740997  163.666000  168.621506  168.621506
# 2 2021-11-01  168.089996  168.792999  164.600998  165.905502  165.905502
# 3 2021-11-02  165.750504  166.556000  164.177505  165.637497  165.637497
# 4 2021-11-03  165.449997  169.746002  164.876007  169.199997  169.199997
#
#       Volume Stock Name         MA7        MA20        MA10      MACD  \
# 0  114174000       AMZN  169.436571  166.614751  170.105151 -0.644339
# 1  129722000       AMZN  169.132071  166.837676  169.922202 -0.040452
# 2   72178000       AMZN  168.297071  167.158501  169.279051 -0.243565
# 3   52552000       AMZN  168.134214  167.387876  168.622050 -0.088001
# 4   67944000       AMZN  168.588715  167.692851  168.466750  0.389213
#
#        20SD  upper_band  lower_band         EMA  logmomentum
# 0  4.111286  174.837323  158.392179  171.261756     5.143583
# 1  4.092180  175.022037  158.653316  169.501589     5.121708
# 2  3.720357  174.599216  159.717786  167.104198     5.105373
# 3  3.455945  174.299767  160.475986  166.126397     5.103746
# 4  3.324309  174.341469  161.044234  168.175464     5.125154

# %%
def tech_ind(dataset):
    fig,ax = plt.subplots(figsize=(15, 8), dpi = 200)
    x_ = range(3, dataset.shape[0])
    x_ = list(dataset.index)

    ax.plot(dataset['Date'], dataset['MA7'], label='Moving Average (7 days)', color='g', linestyle='--')
    ax.plot(dataset['Date'], dataset['Close'], label='Closing Price', color='#6A5ACD')
    ax.plot(dataset['Date'], dataset['MA20'], label='Moving Average (20 days)', color='r', linestyle='-.')
    plt.title('Technical indicators')
    plt.ylabel('Close (USD)')
    plt.xlabel("Year")
    plt.legend()

    plt.show()

# %%
tech_ind(stock_df)

# %%
stock_df.set_index('Date', inplace=True)

# %%
merged_df = stock_df.merge(daily_sentiment, left_index=True, right_index=True, how='inner')

# %%
merged_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-10-28  170.104996  173.949997  169.300003  172.328506  172.328506
# 2021-10-29  165.001007  168.740997  163.666000  168.621506  168.621506
# 2021-11-01  168.089996  168.792999  164.600998  165.905502  165.905502
# 2021-11-02  165.750504  166.556000  164.177505  165.637497  165.637497
# 2021-11-03  165.449997  169.746002  164.876007  169.199997  169.199997
#
#                Volume Stock Name         MA7        MA20        MA10  \
# Date
# 2021-10-28  114174000       AMZN  169.436571  166.614751  170.105151
# 2021-10-29  129722000       AMZN  169.132071  166.837676  169.922202
# 2021-11-01   72178000       AMZN  168.297071  167.158501  169.279051
# 2021-11-02   52552000       AMZN  168.134214  167.387876  168.622050
# 2021-11-03   67944000       AMZN  168.588715  167.692851  168.466750
#
#                 MACD      20SD  upper_band  lower_band         EMA  \
# Date
# 2021-10-28 -0.644339  4.111286  174.837323  158.392179  171.261756
# 2021-10-29 -0.040452  4.092180  175.022037  158.653316  169.501589
# 2021-11-01 -0.243565  3.720357  174.599216  159.717786  167.104198
# 2021-11-02 -0.088001  3.455945  174.299767  160.475986  166.126397
# 2021-11-03  0.389213  3.324309  174.341469  161.044234  168.175464
#
#             logmomentum  sentiment_score  Negative   Neutral  Positive
# Date
# 2021-10-28     5.143583        -0.001450  0.068295  0.850636  0.081023
# 2021-10-29     5.121708         0.140447  0.059438  0.853000  0.087563
# 2021-11-01     5.105373         0.369745  0.017364  0.876727  0.105818
# 2021-11-02     5.103746         0.336614  0.060286  0.808714  0.130857
# 2021-11-03     5.125154         0.260729  0.019143  0.871571  0.109286

# %%
correlation = merged_df.select_dtypes(include='number').corr()
print(correlation['Close'].sort_values(ascending=False))
# Out:
# Close              1.000000
# Adj Close          1.000000
# EMA                0.998155
# logmomentum        0.997593
# Low                0.996510
# High               0.996445
# Open               0.991386
# MA7                0.972165
# MA10               0.956169
# lower_band         0.906552
# MA20               0.903007
# upper_band         0.828262
# sentiment_score    0.155882
# Neutral            0.110582
# Positive           0.005094
# Negative          -0.181703
# Volume            -0.181844
# 20SD              -0.407387
# MACD              -0.485700
# Name: Close, dtype: float64

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >

# %%
merged_df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Stock Name',
#        'MA7', 'MA20', 'MA10', 'MACD', '20SD', 'upper_band', 'lower_band',
#        'EMA', 'logmomentum', 'sentiment_score', 'Negative', 'Neutral',
#        'Positive'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
scaled_df = scaler.fit_transform(stock_df[['MA7', 'MA20', 'MA10', 'MACD', '20SD', 
                                           'upper_band', 'lower_band', 'EMA', 
                                           'logmomentum', 'Close']])

# %% [markdown]
# ## Using LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.regularizers import l2

# %%
features = ['MA7', 'MA20', 'MA10', 'MACD', '20SD', 'upper_band', 'lower_band',
       'EMA', 'logmomentum','sentiment_score', 'Negative', 'Neutral', 'Positive',]
target = 'Close'


# Feature scaler
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(merged_df[features])

# Target scaler
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(merged_df[[target]])

scaled_data = np.hstack((X_scaled, y_scaled))

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length, :-1]) 
        y.append(data[i+seq_length, -1])   
    return np.array(X), np.array(y)

# %%
seq_length = 10  
X, y = create_sequences(scaled_data, seq_length)

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
input_dim = X_train.shape[1]
feature_size = X_train.shape[2]
output_dim = 1

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
# from keras.layers import LSTM, Dense, Dropout, LayerNormalization
# model = tf.keras.Sequential([
#         LSTM(units=1024, return_sequences=True, input_shape=(input_dim, feature_size), recurrent_dropout=0.3),
#         LSTM(units=512, return_sequences=True, recurrent_dropout=0.3),
#         LSTM(units=256, return_sequences=True, recurrent_dropout=0.3),
#         LSTM(units=128, return_sequences=True, recurrent_dropout=0.3),
#         LSTM(units=64, recurrent_dropout=0.3),
#         Dense(32),
#         Dense(16),
#         Dense(8),
#         Dense(units=output_dim)
#     ])


model = tf.keras.Sequential([
        # First LSTM with input normalization
        tf.keras.layers.BatchNormalization(input_shape=(input_dim, feature_size)),
        LSTM(units=128, return_sequences=True, recurrent_dropout=0.2, 
             kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        # Second LSTM
        LSTM(units=64, recurrent_dropout=0.2, 
             kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        # Normalize before dense layers
        tf.keras.layers.BatchNormalization(),
        # Dense layers with dropout
        Dense(32, activation='gelu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        Dropout(0.3),
        Dense(16, activation='gelu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        Dropout(0.3),
        Dense(units=output_dim)
    ])
# Out:
# C:\Users\anike\anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test),callbacks=[early_stop])
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 3.0246 - val_loss: 2.3832
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5256 - val_loss: 2.0791
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0996 - val_loss: 1.8242
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8948 - val_loss: 1.6172
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6633 - val_loss: 1.4447
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4665 - val_loss: 1.3114
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3302 - val_loss: 1.2106
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2386 - val_loss: 1.1206
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1469 - val_loss: 1.0449
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0809 - val_loss: 0.9932
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0219 - val_loss: 0.9388
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9702 - val_loss: 0.8890
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9317 - val_loss: 0.8479
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8696 - val_loss: 0.8092
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8387 - val_loss: 0.7725
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8123 - val_loss: 0.7380
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7592 - val_loss: 0.7068
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7324 - val_loss: 0.6783
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6790 - val_loss: 0.6480
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6614 - val_loss: 0.6169
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6276 - val_loss: 0.5899
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6048 - val_loss: 0.5638
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5737 - val_loss: 0.5386
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5580 - val_loss: 0.5116
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5412 - val_loss: 0.4895
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5021 - val_loss: 0.4673
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4763 - val_loss: 0.4452
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4573 - val_loss: 0.4282
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4453 - val_loss: 0.4050
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4206 - val_loss: 0.3882
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3920 - val_loss: 0.3709
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3874 - val_loss: 0.3521
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3731 - val_loss: 0.3364
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3439 - val_loss: 0.3238
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3335 - val_loss: 0.3044
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3101 - val_loss: 0.2892
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3070 - val_loss: 0.2771
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2975 - val_loss: 0.2644
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2716 - val_loss: 0.2510
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2623 - val_loss: 0.2377
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2516 - val_loss: 0.2280
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2328 - val_loss: 0.2146
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2226 - val_loss: 0.2036
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2189 - val_loss: 0.1943
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2050 - val_loss: 0.1880
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1947 - val_loss: 0.1759
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1951 - val_loss: 0.1673
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1774 - val_loss: 0.1641
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1792 - val_loss: 0.1510
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1623 - val_loss: 0.1442

# %%
print("X_test shape:", X_test.shape)
# Out:
# X_test shape: (45, 10, 13)

# %%
# 🧠 Predict stock prices
y_pred = model.predict(X_test)

# ✅ Extract the last timestep features (shape: [samples, 14])
last_features = X_test[:, -1, :]  # shape: (samples, 14)

# ✅ Append predictions as the 15th column
reconstructed_pred = np.concatenate((last_features, y_pred), axis=1)  # shape: (samples, 15)
reconstructed_true = np.concatenate((last_features, y_test.reshape(-1, 1)), axis=1)  # shape: (samples, 15)

# ✅ Inverse transform using the scaler (which was fit on 15 features)
y_pred_actual = scaler_y.inverse_transform(reconstructed_pred)[:, -1]
y_test_actual = scaler_y.inverse_transform(reconstructed_true)[:, -1]

# 📈 Plot actual vs predicted prices
plt.figure(figsize=(12, 6))
sns.lineplot(x=range(len(y_test_actual)), y=y_test_actual, label='Actual Price', color='red')
sns.lineplot(x=range(len(y_pred_actual)), y=y_pred_actual, label='Predicted Price', color='blue')
plt.title("Stock Price Prediction using LSTM + Sentiment")
plt.xlabel("Time Step")
plt.ylabel("Stock Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.010441001419467284

# %%
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.08436590072652256

# %%
print(mean_squared_error(y_test,y_pred)**0.5)
# Out:
# 0.10218121852604461

# %%
# Plot loss curve
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()

# %% [markdown]
# # Without Sentiment analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('stock_tweets.csv')

# %%
df.head()
# Out:
#                         Date  \
# 0  2022-09-29 23:41:16+00:00
# 1  2022-09-29 23:24:43+00:00
# 2  2022-09-29 23:18:08+00:00
# 3  2022-09-29 22:40:07+00:00
# 4  2022-09-29 22:27:05+00:00
#
#                                                Tweet Stock Name Company Name
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.

# %%
stock_name = 'AMZN'

# %%
amzn_df = df[df['Stock Name'] == stock_name].copy()

# %%
amzn_df['Date'] = pd.to_datetime(amzn_df['Date'])

# %%
amzn_df['Date'] = amzn_df['Date'].dt.date

# %%
amzn_df.head()
# Out:
#              Date                                              Tweet  \
# 48351  2022-09-29  A group of lawmakers led by Sen. Elizabeth War...
# 48352  2022-09-29  $NIO just because I'm down money doesn't mean ...
# 48353  2022-09-29  Today’s drop in $SPX is a perfect example of w...
# 48354  2022-09-29  Druckenmiller owned $CVNA this year \nMunger b...
# 48355  2022-09-29  Top 10 $QQQ Holdings \n\nAnd Credit Rating\n\n...
#
#       Stock Name      Company Name
# 48351       AMZN  Amazon.com, Inc.
# 48352       AMZN  Amazon.com, Inc.
# 48353       AMZN  Amazon.com, Inc.
# 48354       AMZN  Amazon.com, Inc.
# 48355       AMZN  Amazon.com, Inc.

# %%
all_stocks = pd.read_csv('stock_yfinance_data.csv')
print(all_stocks.shape)
all_stocks.head()
# Out:
# (6300, 8)
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 1  2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2  2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 3  2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 4  2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
#
#      Volume Stock Name
# 0  53868000       TSLA
# 1  51094200       TSLA
# 2  91449900       TSLA
# 3  55297800       TSLA
# 4  43898400       TSLA

# %%
stock_df = all_stocks[all_stocks['Stock Name'] == 'AMZN']

# %%
stock_df['Date'] = pd.to_datetime(stock_df['Date'])
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_23188\3629404903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_df['Date'] = pd.to_datetime(stock_df['Date'])

# %%
def get_tech_ind(d):
    data=d.copy()
    data['MA7'] = data.iloc[:,4].rolling(window=7).mean() #Close column
    data['MA20'] = data.iloc[:,4].rolling(window=20).mean() #Close Column
    data['MA10'] = data['Close'].rolling(window=10).mean()

    data['MACD'] = data.iloc[:,4].ewm(span=26).mean() - data.iloc[:,1].ewm(span=12,adjust=False).mean()
    #This is the difference of Closing price and Opening Price

    # Create Bollinger Bands
    data['20SD'] = data.iloc[:, 4].rolling(20).std()
    data['upper_band'] = data['MA20'] + (data['20SD'] * 2)
    data['lower_band'] = data['MA20'] - (data['20SD'] * 2)

    # Create Exponential moving average
    data['EMA'] = data.iloc[:,4].ewm(com=0.5).mean()

    # Create LogMomentum
    data['logmomentum'] = np.log(data.iloc[:,4] - 1)

    return data

# %%
tech_df = get_tech_ind(stock_df)
stock_df = tech_df.iloc[20:,:].reset_index(drop=True)
stock_df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-10-28  170.104996  173.949997  169.300003  172.328506  172.328506
# 1 2021-10-29  165.001007  168.740997  163.666000  168.621506  168.621506
# 2 2021-11-01  168.089996  168.792999  164.600998  165.905502  165.905502
# 3 2021-11-02  165.750504  166.556000  164.177505  165.637497  165.637497
# 4 2021-11-03  165.449997  169.746002  164.876007  169.199997  169.199997
#
#       Volume Stock Name         MA7        MA20        MA10      MACD  \
# 0  114174000       AMZN  169.436571  166.614751  170.105151 -0.644339
# 1  129722000       AMZN  169.132071  166.837676  169.922202 -0.040452
# 2   72178000       AMZN  168.297071  167.158501  169.279051 -0.243565
# 3   52552000       AMZN  168.134214  167.387876  168.622050 -0.088001
# 4   67944000       AMZN  168.588715  167.692851  168.466750  0.389213
#
#        20SD  upper_band  lower_band         EMA  logmomentum
# 0  4.111286  174.837323  158.392179  171.261756     5.143583
# 1  4.092180  175.022037  158.653316  169.501589     5.121708
# 2  3.720357  174.599216  159.717786  167.104198     5.105373
# 3  3.455945  174.299767  160.475986  166.126397     5.103746
# 4  3.324309  174.341469  161.044234  168.175464     5.125154

# %%
def tech_ind(dataset):
    fig,ax = plt.subplots(figsize=(15, 8), dpi = 200)
    x_ = range(3, dataset.shape[0])
    x_ = list(dataset.index)

    ax.plot(dataset['Date'], dataset['MA7'], label='Moving Average (7 days)', color='g', linestyle='--')
    ax.plot(dataset['Date'], dataset['Close'], label='Closing Price', color='#6A5ACD')
    ax.plot(dataset['Date'], dataset['MA20'], label='Moving Average (20 days)', color='r', linestyle='-.')
    plt.title('Technical indicators')
    plt.ylabel('Close (USD)')
    plt.xlabel("Year")
    plt.legend()

    plt.show()

# %%
tech_ind(stock_df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
stock_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Stock Name', 'MA7', 'MA20', 'MA10', 'MACD', '20SD', 'upper_band',
#        'lower_band', 'EMA', 'logmomentum'],
#       dtype='object')

# %%
scaled_df= scaler.fit_transform(stock_df[['MA7', 'MA20', 'MA10', 'MACD', '20SD', 'upper_band', 'lower_band',
       'EMA', 'logmomentum','Close']])

# %%
scaled_df = pd.DataFrame(
    scaled_df, 
    columns=['MA7', 'MA20', 'MA10', 'MACD', '20SD', 
             'upper_band', 'lower_band', 'EMA', 
             'logmomentum', 'Close']
)

# %%
features = scaled_df[['MA7', 'MA20', 'MA10', 'MACD', '20SD', 
                      'upper_band', 'lower_band', 'EMA', 
                      'logmomentum']]
target = scaled_df['Close']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.regularizers import l2

# %%
features = ['MA7', 'MA20', 'MA10', 'MACD', '20SD', 'upper_band', 'lower_band',
       'EMA', 'logmomentum']
target = 'Close'

# Feature scaler
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(stock_df[features])

# Target scaler
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(stock_df[[target]])

scaled_data = np.hstack((X_scaled, y_scaled))

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length, :-1]) 
        y.append(data[i+seq_length, -1])   
    return np.array(X), np.array(y)

# %%
seq_length = 10  
X, y = create_sequences(scaled_data, seq_length)

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
input_dim = X_train.shape[1]
feature_size = X_train.shape[2]
output_dim = 1

# %%
# from keras.layers import LSTM, Dense, Dropout, LayerNormalization
# model = tf.keras.Sequential([
#         LSTM(units=1024, return_sequences=True, input_shape=(input_dim, feature_size), recurrent_dropout=0.3),
#         LSTM(units=512, return_sequences=True, recurrent_dropout=0.3),
#         LSTM(units=256, return_sequences=True, recurrent_dropout=0.3),
#         LSTM(units=128, return_sequences=True, recurrent_dropout=0.3),
#         LSTM(units=64, recurrent_dropout=0.3),
#         Dense(32),
#         Dense(16),
#         Dense(8),
#         Dense(units=output_dim)
#     ])

model = tf.keras.Sequential([
        # First LSTM with input normalization
        tf.keras.layers.BatchNormalization(input_shape=(input_dim, feature_size)),
        LSTM(units=128, return_sequences=True, recurrent_dropout=0.2, 
             kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        # Second LSTM
        LSTM(units=64, recurrent_dropout=0.2, 
             kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        # Normalize before dense layers
        tf.keras.layers.BatchNormalization(),
        # Dense layers with dropout
        Dense(32, activation='gelu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        Dropout(0.3),
        Dense(16, activation='gelu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        Dropout(0.3),
        Dense(units=output_dim)
    ])
# Out:
# C:\Users\anike\anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test),callbacks=[early_stop])
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 3.3813 - val_loss: 2.3505
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5515 - val_loss: 2.1105
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1610 - val_loss: 1.8873
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9415 - val_loss: 1.6896
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7399 - val_loss: 1.5178
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5466 - val_loss: 1.3794
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4025 - val_loss: 1.2705
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2985 - val_loss: 1.1746
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2175 - val_loss: 1.0958
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1196 - val_loss: 1.0296
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0614 - val_loss: 0.9714
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0140 - val_loss: 0.9234
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9554 - val_loss: 0.8796
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8981 - val_loss: 0.8403
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8577 - val_loss: 0.8035
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8305 - val_loss: 0.7698
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8087 - val_loss: 0.7444
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7627 - val_loss: 0.7177
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7343 - val_loss: 0.6840
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7145 - val_loss: 0.6556
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6767 - val_loss: 0.6304
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6453 - val_loss: 0.6066
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6279 - val_loss: 0.5829
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5937 - val_loss: 0.5610
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5672 - val_loss: 0.5396
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5577 - val_loss: 0.5153
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5313 - val_loss: 0.4960
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5116 - val_loss: 0.4772
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4882 - val_loss: 0.4590
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4726 - val_loss: 0.4414
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4524 - val_loss: 0.4242
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4397 - val_loss: 0.4073
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4211 - val_loss: 0.3914
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4036 - val_loss: 0.3746
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3858 - val_loss: 0.3608
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3689 - val_loss: 0.3448
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3628 - val_loss: 0.3325
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3444 - val_loss: 0.3204
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3399 - val_loss: 0.3042
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3127 - val_loss: 0.2925
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3103 - val_loss: 0.2794
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2980 - val_loss: 0.2675
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2836 - val_loss: 0.2562
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2663 - val_loss: 0.2483
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2626 - val_loss: 0.2362
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2467 - val_loss: 0.2283
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2507 - val_loss: 0.2170
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2350 - val_loss: 0.2095
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2264 - val_loss: 0.1993
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2214 - val_loss: 0.1916

# %%
print("X_test shape:", X_test.shape)
# Out:
# X_test shape: (45, 10, 9)

# %%
# 🧠 Predict stock prices
y_pred = model.predict(X_test)

# ✅ Extract the last timestep features (shape: [samples, 14])
last_features = X_test[:, -1, :]  # shape: (samples, 14)

# ✅ Append predictions as the 15th column
reconstructed_pred = np.concatenate((last_features, y_pred), axis=1)  # shape: (samples, 15)
reconstructed_true = np.concatenate((last_features, y_test.reshape(-1, 1)), axis=1)  # shape: (samples, 15)

# ✅ Inverse transform using the scaler (which was fit on 15 features)
y_pred_actual = scaler_y.inverse_transform(reconstructed_pred)[:, -1]
y_test_actual = scaler_y.inverse_transform(reconstructed_true)[:, -1]

# 📈 Plot actual vs predicted prices
plt.figure(figsize=(12, 6))
sns.lineplot(x=range(len(y_test_actual)), y=y_test_actual, label='Actual Price', color='red')
sns.lineplot(x=range(len(y_pred_actual)), y=y_pred_actual, label='Predicted Price', color='blue')
plt.title("Stock Price Prediction using LSTM + Sentiment")
plt.xlabel("Time Step")
plt.ylabel("Stock Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.008663959444536715

# %%
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.08289318610026875

# %%
print(mean_squared_error(y_test,y_pred)**0.5)
# Out:
# 0.09308039237420905

# %%
# Plot loss curve
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()
